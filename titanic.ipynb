# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np 
import pandas as pd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
## setfile paths for all data given
titanic_file_path= '/kaggle/input/titanic'
titanic_gender_path='/kaggle/input/titanic/gender_submission.csv'
titanic_test_data_path= '/kaggle/input/titanic/test.csv'
titanic_train_data_path='/kaggle/input/titanic/train.csv'
## use pandas to read the data then create a dataframe for the data
titanic_train_data=pd.read_csv('/kaggle/input/titanic/train.csv', index_col=0)
titanic_gender_sub_data= pd.read_csv('/kaggle/input/titanic/gender_submission.csv',index_col=0)
titanic_test_data= pd.read_csv('/kaggle/input/titanic/test.csv',index_col=0)

#reproducability
np.random.seed(0)
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
## data cleaning section

titanic_train_data.head()
#how many missing values
missing_value_count=titanic_train_data.isnull().sum()
missing_value_count[0:12]

#percentage of missing data

#total missing data
total_cells=np.product(titanic_train_data.shape)
total_missing= missing_value_count.sum()

#calculate percentage
percent_missing=(total_missing/total_missing/total_cells)*100
print(percent_missing)

#one approach, fill missing data with 0
titanic_train_data.fillna(method='bfill', axis=0).fillna(0)
titanic_train_data.Cabin.head
print(titanic_train_data.isnull().sum())

#next approach, good in some instances, drop missing data
titanic_train_data.dropna()
columns_with_na_dropped = titanic_train_data.dropna(axis=1)
columns_with_na_dropped.head()
print(titanic_train_data.isnull().sum())
# Out:
# 0.010203040506070809
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64
# Survived      0
# Pclass        0
# Name          0
# Sex           0
# Age         177
# SibSp         0
# Parch         0
# Ticket        0
# Fare          0
# Cabin       687
# Embarked      2
# dtype: int64

# %%
#visualing data
grid = sns.FacetGrid(titanic_train_data, col='Survived', row='Pclass', aspect=1)
grid.map(plt.hist, 'Age', alpha=.5, bins=30)
grid.add_legend();

# %%
## feature engineering section
