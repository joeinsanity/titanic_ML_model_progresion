# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error
import numpy as np 
import pandas as pd

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
## setfile paths for all data given
titanic_file_path= '/kaggle/input/titanic'
titanic_gender_path='/kaggle/input/titanic/gender_submission.csv'
titanic_test_data_path= '/kaggle/input/titanic/test.csv'
titanic_train_data_path='/kaggle/input/titanic/train.csv'
## use pandas to read the data then create a dataframe for the data
titanic_test_data=pd.read_csv('/kaggle/input/titanic/test.csv', index_col=0)
titanic_gender_sub_data= pd.read_csv('/kaggle/input/titanic/gender_submission.csv')


## pick out factors that may predict outcome
passenger_details= ['Pclass','Sex', 'Age','SibSp','Parch','Ticket','Fare','Cabin','Embarked']
X=titanic_test_data[passenger_details]
train_predictors= titanic_test_data[passenger_details]
## set the validation data
y= titanic_gender_sub_data.Survived
# Out:
# /kaggle/input/titanic/train.csv
# /kaggle/input/titanic/test.csv
# /kaggle/input/titanic/gender_submission.csv

# %%
titanic_gender_sub_data.head()
titanic_gender_sub_data.dtypes
# Out:
# PassengerId    int64
# Survived       int64
# dtype: object

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder
##set up data to train
train_X,val_x,train_y,val_y= train_test_split(X,y,random_state=0)

## beginning of one hot coding implementation
train_predictors= passender_details
test_predictors= titanic_gender_sub_data
one_hot_encoded_training_predicters= pd.get_dummies(train_predictors)

s=(train_X.dtypes== 'object')
object_cols= list(s[s].index)

OH_encoder=OneHotEncoder(handle_unknown='ignore',sparse_output= False)
OH_cols_train= pd.DataFrame(OH_encoder.fit_transform(train_X[object_cols]))
OH_cols_valid= pd.DataFrame(OH_encoder.transform(val_x[object_cols]))

OH_cols_train.index = train_X.index
OH_cols_valid.index = val_x.index 

num_X_train= train_X.drop(object_cols,axis=1)
num_X_valid= val_x.drop(object_cols,axis=1)

OH_X_train=pd.concat([num_X_train,OH_cols_train], axis=1)
OH_X_valid= pd.concat([num_X_train,OH_cols_valid],axis=1)

OH_X_train.columns = OH_X_train.columns.astype(object)
OH_X_valid.columns= OH_X_train.columns.astype(object)

## random forest regressor, fitting and training 
titanic_forest_model=RandomForestRegressor(random_state=1)

titanic_forest_model.fit(train_X,train_y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 7
#       2 from sklearn.preprocessing import OneHotEncoder
#       4 train_X,val_x,train_y,val_y= train_test_split(X,y,random_state=0)
# ----> 7 train_predictors= passender_details
#       8 test_predictors= titanic_gender_sub_data
#       9 one_hot_encoded_training_predicters= pd.get_dummies(train_predictors)
#
# NameError: name 'passender_details' is not defined
